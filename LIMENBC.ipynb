# %%
import os, importlib.util
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from lime.lime_tabular import LimeTabularExplainer

# 1) Dynamically load your teammate’s module
spec = importlib.util.spec_from_file_location(
    "nbc_mod", os.path.join(os.getcwd(), "nbc.py")
)
nbc_mod = importlib.util.module_from_spec(spec)
spec.loader.exec_module(nbc_mod)  # :contentReference[oaicite:0]{index=0}

# 2) Load & preprocess
df = pd.read_csv("mushroom_dataset.csv")
X, y, encoders = nbc_mod.preprocess_data(df)

# 3) Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# 4) Train the custom NBC
nbc = nbc_mod.NBC()
nbc.train(X_train, y_train)

# 5) Build a predict_proba wrapper
def predict_proba_custom(arr):
    """
    arr: numpy array of shape (n_samples, n_features)
    returns: array of shape (n_samples, n_classes)
    """
    df_in = pd.DataFrame(arr, columns=X_train.columns)
    probs = []
    for _, row in df_in.iterrows():
        # use predict_one to get (class, raw_score)
        # but we need all class raw scores
        # so we’ll reimplement the core loop here:
        raw = {}
        for c in nbc.output_classes:
            p = nbc.output_class_probs[c]
            for ft, val in row.items():
                p *= nbc.per_class_feature_probs[c][ft][val]
            raw[c] = p
        # normalize
        total = sum(raw.values())
        probs.append([ raw[c]/total for c in nbc.output_classes ])
    return np.array(probs)

# Quick sanity check
print("Custom NBC test accuracy:",
      np.mean(nbc.predict(X_test) == y_test))

# 6) Set up LIME with categorical metadata
feature_names        = X_train.columns.tolist()
categorical_features = list(range(len(feature_names)))
categorical_names    = {
    i: encoders[col].classes_.tolist()
    for i, col in enumerate(feature_names)
}

explainer = LimeTabularExplainer(
    training_data         = X_train.values,
    feature_names         = feature_names,
    class_names           = [str(c) for c in nbc.output_classes],
    mode                  = "classification",
    categorical_features  = categorical_features,
    categorical_names     = categorical_names,
    discretize_continuous = False
)

# 7) Explain a test instance (e.g. index 0)
idx = 0
exp = explainer.explain_instance(
    data_row     = X_test.iloc[idx].values,
    predict_fn   = predict_proba_custom,
    num_features = 5
)

print(f"\nLIME explanation for custom NBC instance #{idx}:")
for feat, w in exp.as_list():
    print(f"  {feat}: {w:.4f}")

exp.save_to_file(f"lime_custom_nbc_{idx}.html")
print(f"Saved HTML → lime_custom_nbc_{idx}.html")
# Out:
# Custom NBC test accuracy: 0.9458572600492207
#
# LIME explanation for custom NBC instance #0:
#   odor=n: -0.3845
#   spore-print-color=n: -0.1185
#   stalk-surface-above-ring=s: -0.1183
#   gill-size=b: -0.1181
#   bruises=f: 0.0808
# Saved HTML → lime_custom_nbc_0.html

# %%
# %run nbc.py
# Out:
# Loading mushroom dataset...
# Dataset shape: (8124, 23)
# First 5 rows:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]
# Preprocessing data...
# Training Naive Bayes classifier (off-the-shelf)...
# off-the-shelf model accuracy: 0.9459
# Training Naive Bayes classifier (custom implementation)...
#
# === Feature: cap-shape ===
# Value = 0:
#   P(e | cap-shape=0) = 0.8726
#   P(p | cap-shape=0) = 0.1274
# Value = 1:
#   P(e | cap-shape=1) = 0.2000
#   P(p | cap-shape=1) = 0.8000
# Value = 2:
#   P(e | cap-shape=2) = 0.5142
#   P(p | cap-shape=2) = 0.4858
# Value = 3:
#   P(e | cap-shape=3) = 0.2818
#   P(p | cap-shape=3) = 0.7182
# Value = 4:
#   P(e | cap-shape=4) = 0.9583
#   P(p | cap-shape=4) = 0.0417
# Value = 5:
#   P(e | cap-shape=5) = 0.5342
#   P(p | cap-shape=5) = 0.4658
#
# === Feature: cap-surface ===
# Value = 0:
#   P(e | cap-surface=0) = 0.6714
#   P(p | cap-surface=0) = 0.3286
# Value = 1:
#   P(e | cap-surface=1) = 0.2500
#   P(p | cap-surface=1) = 0.7500
# Value = 2:
#   P(e | cap-surface=2) = 0.4509
#   P(p | cap-surface=2) = 0.5491
# Value = 3:
#   P(e | cap-surface=3) = 0.4642
#   P(p | cap-surface=3) = 0.5358
#
# === Feature: cap-color ===
# Value = 0:
#   P(e | cap-color=0) = 0.3096
#   P(p | cap-color=0) = 0.6904
# Value = 1:
#   P(e | cap-color=1) = 0.6924
#   P(p | cap-color=1) = 0.3076
# Value = 2:
#   P(e | cap-color=2) = 0.4142
#   P(p | cap-color=2) = 0.5858
# Value = 3:
#   P(e | cap-color=3) = 0.5651
#   P(p | cap-color=3) = 0.4349
# Value = 4:
#   P(e | cap-color=4) = 0.5553
#   P(p | cap-color=4) = 0.4447
# Value = 5:
#   P(e | cap-color=5) = 0.4206
#   P(p | cap-color=5) = 0.5794
# Value = 6:
#   P(e | cap-color=6) = 0.9231
#   P(p | cap-color=6) = 0.0769
# Value = 7:
#   P(e | cap-color=7) = 0.9375
#   P(p | cap-color=7) = 0.0625
# Value = 8:
#   P(e | cap-color=8) = 0.6932
#   P(p | cap-color=8) = 0.3068
# Value = 9:
#   P(e | cap-color=9) = 0.3583
#   P(p | cap-color=9) = 0.6417
#
# === Feature: bruises ===
# Value = 0:
#   P(e | bruises=0) = 0.3045
#   P(p | bruises=0) = 0.6955
# Value = 1:
#   P(e | bruises=1) = 0.8204
#   P(p | bruises=1) = 0.1796
#
# === Feature: odor ===
# Value = 0:
#   P(e | odor=0) = 0.9964
#   P(p | odor=0) = 0.0036
# Value = 1:
#   P(e | odor=1) = 0.0072
#   P(p | odor=1) = 0.9928
# Value = 2:
#   P(e | odor=2) = 0.0007
#   P(p | odor=2) = 0.9993
# Value = 3:
#   P(e | odor=3) = 0.9962
#   P(p | odor=3) = 0.0038
# Value = 4:
#   P(e | odor=4) = 0.0323
#   P(p | odor=4) = 0.9677
# Value = 5:
#   P(e | odor=5) = 0.9672
#   P(p | odor=5) = 0.0328
# Value = 6:
#   P(e | odor=6) = 0.0059
#   P(p | odor=6) = 0.9941
# Value = 7:
#   P(e | odor=7) = 0.0024
#   P(p | odor=7) = 0.9976
# Value = 8:
#   P(e | odor=8) = 0.0025
#   P(p | odor=8) = 0.9975
#
# === Feature: gill-attachment ===
# Value = 0:
#   P(e | gill-attachment=0) = 0.8961
#   P(p | gill-attachment=0) = 0.1039
# Value = 1:
#   P(e | gill-attachment=1) = 0.5085
#   P(p | gill-attachment=1) = 0.4915
#
# === Feature: gill-spacing ===
# Value = 0:
#   P(e | gill-spacing=0) = 0.4447
#   P(p | gill-spacing=0) = 0.5553
# Value = 1:
#   P(e | gill-spacing=1) = 0.9107
#   P(p | gill-spacing=1) = 0.0893
#
# === Feature: gill-size ===
# Value = 0:
#   P(e | gill-size=0) = 0.6997
#   P(p | gill-size=0) = 0.3003
# Value = 1:
#   P(e | gill-size=1) = 0.1111
#   P(p | gill-size=1) = 0.8889
#
# === Feature: gill-color ===
# Value = 0:
#   P(e | gill-color=0) = 0.0008
#   P(p | gill-color=0) = 0.9992
# Value = 1:
#   P(e | gill-color=1) = 0.9865
#   P(p | gill-color=1) = 0.0135
# Value = 2:
#   P(e | gill-color=2) = 0.3182
#   P(p | gill-color=2) = 0.6818
# Value = 3:
#   P(e | gill-color=3) = 0.2906
#   P(p | gill-color=3) = 0.7094
# Value = 4:
#   P(e | gill-color=4) = 0.8370
#   P(p | gill-color=4) = 0.1630
# Value = 5:
#   P(e | gill-color=5) = 0.8954
#   P(p | gill-color=5) = 0.1046
# Value = 6:
#   P(e | gill-color=6) = 0.9773
#   P(p | gill-color=6) = 0.0227
# Value = 7:
#   P(e | gill-color=7) = 0.5567
#   P(p | gill-color=7) = 0.4433
# Value = 8:
#   P(e | gill-color=8) = 0.0588
#   P(p | gill-color=8) = 0.9412
# Value = 9:
#   P(e | gill-color=9) = 0.9055
#   P(p | gill-color=9) = 0.0945
# Value = 10:
#   P(e | gill-color=10) = 0.8063
#   P(p | gill-color=10) = 0.1937
# Value = 11:
#   P(e | gill-color=11) = 0.6876
#   P(p | gill-color=11) = 0.3124
#
# === Feature: stalk-shape ===
# Value = 0:
#   P(e | stalk-shape=0) = 0.4607
#   P(p | stalk-shape=0) = 0.5393
# Value = 1:
#   P(e | stalk-shape=1) = 0.5629
#   P(p | stalk-shape=1) = 0.4371
#
# === Feature: stalk-root ===
# Value = 0:
#   P(e | stalk-root=0) = 0.2952
#   P(p | stalk-root=0) = 0.7048
# Value = 1:
#   P(e | stalk-root=1) = 0.5130
#   P(p | stalk-root=1) = 0.4870
# Value = 2:
#   P(e | stalk-root=2) = 0.9054
#   P(p | stalk-root=2) = 0.0946
# Value = 3:
#   P(e | stalk-root=3) = 0.7785
#   P(p | stalk-root=3) = 0.2215
# Value = 4:
#   P(e | stalk-root=4) = 0.9921
#   P(p | stalk-root=4) = 0.0079
#
# === Feature: stalk-surface-above-ring ===
# Value = 0:
#   P(e | stalk-surface-above-ring=0) = 0.7520
#   P(p | stalk-surface-above-ring=0) = 0.2480
# Value = 1:
#   P(e | stalk-surface-above-ring=1) = 0.0569
#   P(p | stalk-surface-above-ring=1) = 0.9431
# Value = 2:
#   P(e | stalk-surface-above-ring=2) = 0.7070
#   P(p | stalk-surface-above-ring=2) = 0.2930
# Value = 3:
#   P(e | stalk-surface-above-ring=3) = 0.6000
#   P(p | stalk-surface-above-ring=3) = 0.4000
#
# === Feature: stalk-surface-below-ring ===
# Value = 0:
#   P(e | stalk-surface-below-ring=0) = 0.7530
#   P(p | stalk-surface-below-ring=0) = 0.2470
# Value = 1:
#   P(e | stalk-surface-below-ring=1) = 0.0610
#   P(p | stalk-surface-below-ring=1) = 0.9390
# Value = 2:
#   P(e | stalk-surface-below-ring=2) = 0.6924
#   P(p | stalk-surface-below-ring=2) = 0.3076
# Value = 3:
#   P(e | stalk-surface-below-ring=3) = 0.7047
#   P(p | stalk-surface-below-ring=3) = 0.2953
#
# === Feature: stalk-color-above-ring ===
# Value = 0:
#   P(e | stalk-color-above-ring=0) = 0.0033
#   P(p | stalk-color-above-ring=0) = 0.9967
# Value = 1:
#   P(e | stalk-color-above-ring=1) = 0.0323
#   P(p | stalk-color-above-ring=1) = 0.9677
# Value = 2:
#   P(e | stalk-color-above-ring=2) = 0.9867
#   P(p | stalk-color-above-ring=2) = 0.0133
# Value = 3:
#   P(e | stalk-color-above-ring=3) = 0.9976
#   P(p | stalk-color-above-ring=3) = 0.0024
# Value = 4:
#   P(e | stalk-color-above-ring=4) = 0.0381
#   P(p | stalk-color-above-ring=4) = 0.9619
# Value = 5:
#   P(e | stalk-color-above-ring=5) = 0.9928
#   P(p | stalk-color-above-ring=5) = 0.0072
# Value = 6:
#   P(e | stalk-color-above-ring=6) = 0.3125
#   P(p | stalk-color-above-ring=6) = 0.6875
# Value = 7:
#   P(e | stalk-color-above-ring=7) = 0.6148
#   P(p | stalk-color-above-ring=7) = 0.3852
# Value = 8:
#   P(e | stalk-color-above-ring=8) = 0.1111
#   P(p | stalk-color-above-ring=8) = 0.8889
#
# === Feature: stalk-color-below-ring ===
# Value = 0:
#   P(e | stalk-color-below-ring=0) = 0.0032
#   P(p | stalk-color-below-ring=0) = 0.9968
# Value = 1:
#   P(e | stalk-color-below-ring=1) = 0.0323
#   P(p | stalk-color-below-ring=1) = 0.9677
# Value = 2:
#   P(e | stalk-color-below-ring=2) = 0.9868
#   P(p | stalk-color-below-ring=2) = 0.0132
# Value = 3:
#   P(e | stalk-color-below-ring=3) = 0.9975
#   P(p | stalk-color-below-ring=3) = 0.0025
# Value = 4:
#   P(e | stalk-color-below-ring=4) = 0.1363
#   P(p | stalk-color-below-ring=4) = 0.8637
# Value = 5:
#   P(e | stalk-color-below-ring=5) = 0.9928
#   P(p | stalk-color-below-ring=5) = 0.0072
# Value = 6:
#   P(e | stalk-color-below-ring=6) = 0.3055
#   P(p | stalk-color-below-ring=6) = 0.6945
# Value = 7:
#   P(e | stalk-color-below-ring=7) = 0.6185
#   P(p | stalk-color-below-ring=7) = 0.3815
# Value = 8:
#   P(e | stalk-color-below-ring=8) = 0.0526
#   P(p | stalk-color-below-ring=8) = 0.9474
#
# === Feature: veil-type ===
# Value = 0:
#   P(e | veil-type=0) = 0.5190
#   P(p | veil-type=0) = 0.4810
#
# === Feature: veil-color ===
# Value = 0:
#   P(e | veil-color=0) = 0.9868
#   P(p | veil-color=0) = 0.0132
# Value = 1:
#   P(e | veil-color=1) = 0.9846
#   P(p | veil-color=1) = 0.0154
# Value = 2:
#   P(e | veil-color=2) = 0.5078
#   P(p | veil-color=2) = 0.4922
# Value = 3:
#   P(e | veil-color=3) = 0.1111
#   P(p | veil-color=3) = 0.8889
#
# === Feature: ring-number ===
# Value = 0:
#   P(e | ring-number=0) = 0.0323
#   P(p | ring-number=0) = 0.9677
# Value = 1:
#   P(e | ring-number=1) = 0.4920
#   P(p | ring-number=1) = 0.5080
# Value = 2:
#   P(e | ring-number=2) = 0.8835
#   P(p | ring-number=2) = 0.1165
#
# === Feature: ring-type ===
# Value = 0:
#   P(e | ring-type=0) = 0.3644
#   P(p | ring-type=0) = 0.6356
# Value = 1:
#   P(e | ring-type=1) = 0.9744
#   P(p | ring-type=1) = 0.0256
# Value = 2:
#   P(e | ring-type=2) = 0.0011
#   P(p | ring-type=2) = 0.9989
# Value = 3:
#   P(e | ring-type=3) = 0.0323
#   P(p | ring-type=3) = 0.9677
# Value = 4:
#   P(e | ring-type=4) = 0.7971
#   P(p | ring-type=4) = 0.2029
#
# === Feature: spore-print-color ===
# Value = 0:
#   P(e | spore-print-color=0) = 0.9722
#   P(p | spore-print-color=0) = 0.0278
# Value = 1:
#   P(e | spore-print-color=1) = 0.0332
#   P(p | spore-print-color=1) = 0.9668
# Value = 2:
#   P(e | spore-print-color=2) = 0.8808
#   P(p | spore-print-color=2) = 0.1192
# Value = 3:
#   P(e | spore-print-color=3) = 0.8903
#   P(p | spore-print-color=3) = 0.1097
# Value = 4:
#   P(e | spore-print-color=4) = 0.9737
#   P(p | spore-print-color=4) = 0.0263
# Value = 5:
#   P(e | spore-print-color=5) = 0.0196
#   P(p | spore-print-color=5) = 0.9804
# Value = 6:
#   P(e | spore-print-color=6) = 0.9688
#   P(p | spore-print-color=6) = 0.0312
# Value = 7:
#   P(e | spore-print-color=7) = 0.2447
#   P(p | spore-print-color=7) = 0.7553
# Value = 8:
#   P(e | spore-print-color=8) = 0.9697
#   P(p | spore-print-color=8) = 0.0303
#
# === Feature: population ===
# Value = 0:
#   P(e | population=0) = 0.9963
#   P(p | population=0) = 0.0037
# Value = 1:
#   P(e | population=1) = 0.8360
#   P(p | population=1) = 0.1640
# Value = 2:
#   P(e | population=2) = 0.9964
#   P(p | population=2) = 0.0036
# Value = 3:
#   P(e | population=3) = 0.7094
#   P(p | population=3) = 0.2906
# Value = 4:
#   P(e | population=4) = 0.2966
#   P(p | population=4) = 0.7034
# Value = 5:
#   P(e | population=5) = 0.6191
#   P(p | population=5) = 0.3809
#
# === Feature: habitat ===
# Value = 0:
#   P(e | habitat=0) = 0.6040
#   P(p | habitat=0) = 0.3960
# Value = 1:
#   P(e | habitat=1) = 0.6504
#   P(p | habitat=1) = 0.3496
# Value = 2:
#   P(e | habitat=2) = 0.2865
#   P(p | habitat=2) = 0.7135
# Value = 3:
#   P(e | habitat=3) = 0.8769
#   P(p | habitat=3) = 0.1231
# Value = 4:
#   P(e | habitat=4) = 0.1148
#   P(p | habitat=4) = 0.8852
# Value = 5:
#   P(e | habitat=5) = 0.2521
#   P(p | habitat=5) = 0.7479
# Value = 6:
#   P(e | habitat=6) = 0.9932
#   P(p | habitat=6) = 0.0068
# Custom Model accuracy: 0.9459
